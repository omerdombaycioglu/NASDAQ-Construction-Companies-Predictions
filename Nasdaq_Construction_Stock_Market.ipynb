# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
nasdaqData = pd.read_excel("nasdaq_industry.xlsx")

# %%
nasdaqData = nasdaqData.drop(["Date"],axis=1)
nasdaqDf = pd.DataFrame(nasdaqData)
nasdaqDf
# Out:
#     VCISY     PWR     FER     EME     FIX     ACM  ACSAY     MTZ    APG  \
# 0   28.24  306.63  40.763  445.62  412.01  105.37   9.37  122.32  33.57
# 1   27.53  309.87  40.540  446.11  413.47  104.89   9.44  122.53  34.20
# 2   27.10  308.17  39.926  428.58  370.50  104.49   9.48  121.95  32.84
# 3   28.08  313.36  40.590  431.56  389.30  105.93   9.54  123.73  32.87
# 4   27.84  313.43  40.481  436.79  396.15  108.46   9.55  122.10  33.94
# 5   27.66  311.63  39.580  431.77  390.15  107.37   9.50  120.00  33.21
# 6   27.89  301.63  39.808  446.07  391.04  106.80   9.52  122.89  34.14
# 7   27.85  303.50  39.956  453.21  392.31  108.40   9.62  130.00  35.34
# 8   27.74  304.32  38.728  461.50  390.38  108.04   9.55  132.61  35.25
# 9   27.85  314.62  39.214  475.78  410.99  109.91   9.61  136.54  35.11
# 10  27.09  310.82  38.174  501.88  437.28  114.12   9.45  140.63  36.98
# 11  27.22  320.86  38.910  504.35  443.22  110.72   9.45  141.53  36.75
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
y = nasdaqDf[["VCISY","PWR","FER","EME","FIX","ACM","ACSAY","MTZ","APG","BLD","FLR"]].values
x = nasdaqDf[["VCISY","PWR","FER","EME","FIX","ACM","ACSAY","MTZ","APG","BLD","FLR"]].values
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()
scaler.fit(x_train)
x_train = scaler.transform(x_train)
x_test = scaler.transform(x_test)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

# %%
model = Sequential()
model.add(Dense(32,activation="relu"))
model.add(Dense(16,activation="relu"))
model.add(Dense(8,activation="relu"))

model.add(Dense(11))

model.compile(optimizer="adam",loss="mse")
model.fit(x_train,y_train,validation_data=(x_test,y_test),batch_size=64,epochs=750)
# Out:
# Epoch 1/550
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 63709.1484 - val_loss: 66374.9219
# Epoch 2/550
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - loss: 63707.5703 - val_loss: 66372.9688
# Epoch 3/550
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - loss: 63705.9766 - val_loss: 66370.8906
# Epoch 4/550
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - loss: 63704.3125 - val_loss: 66368.7969
# Epoch 5/550
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 63702.5703 - val_loss: 66366.6797
# Epoch 6/550
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - loss: 63700.7383 - val_loss: 66364.5234
# Epoch 7/550
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - loss: 63698.8633 - val_loss: 66362.4609
# Epoch 8/550
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - loss: 63696.8984 - val_loss: 66360.3984
# Epoch 9/550
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - loss: 63694.8359 - val_loss: 66358.3906
# Epoch 10/550
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 63692.6875 - val_loss: 66356.4922
# Epoch 11/550
# ...

# %%
import seaborn as sbn
kayipVeri = pd.DataFrame(model.history.history)
kayipVeri.plot()
# Out:
# <Axes: >

# %%
tahminSerisi = model.predict(x_test)
tahminDf = pd.DataFrame(tahminSerisi)
tahminDf
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step
#           0           1          2           3           4           5   \
# 0  27.318394  333.559845  42.283825  501.856995  467.036652  114.326324
# 1  19.945948  245.808914  30.783508  369.315460  343.661163   83.941231
# 2  36.029648  441.398956  55.652576  663.864014  617.743286  151.018768
# 3  20.751503  255.723907  32.031227  384.227203  357.540436   87.332520
# 4  19.773716  242.016251  30.586859  363.943085  338.685455   82.878197
# 5  18.886923  233.109192  29.161833  350.167786  325.859009   79.585815
# 6  33.894325  413.863403  52.421722  622.713745  579.478943  141.801956
# 7  31.615444  386.064087  48.909309  580.871094  540.550659  132.288605
# 8  31.765791  388.896790  49.070580  584.919373  544.281067  133.087173
# 9  24.083654  294.962036  37.242847  443.577942  412.790039  100.976067
#
#           6           7          8           9          10
# 0   9.739702  141.523773  37.896687  364.839844  55.288918
# ...

# %%
nasdaqDf.describe()
# Out:
#            VCISY         PWR       FER         EME         FIX         ACM  \
# count  50.000000   50.000000  50.00000   50.000000   50.000000   50.000000
# mean   26.434000  326.097000  40.87800  482.241200  448.488800  110.345400
# std     0.834936   12.050386   1.73333   27.668888   34.966745    3.536425
# min    25.390000  301.630000  38.14000  428.580000  370.500000  104.490000
# 25%    25.662500  316.782500  39.18100  461.940000  429.975000  107.447500
# 50%    26.390000  327.325000  40.94150  479.765000  447.415000  109.690000
# 75%    26.900000  334.790000  42.35000  508.760000  473.887500  112.547500
# max    28.240000  346.600000  43.51000  526.950000  504.120000  116.970000
#
#            ACSAY         MTZ        APG         BLD        FLR
# count  50.000000   50.000000  50.000000   50.000000  50.000000
# mean    9.503400  136.814000  36.555800  355.199800  53.102200
# std     0.465379    7.146797   1.626411   26.856344   2.563943
# ...
